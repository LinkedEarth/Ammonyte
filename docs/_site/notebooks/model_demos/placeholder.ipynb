# %% [raw]
# ---
# title: "Model Demos — Placeholder"
# author: "Maryam Niati, Alexander James, Julien Emile-Geay, Deborah Khider"
# date: last-modified
# abstract: >
#   Replace this cell with a worked example of a specific model: construction, running it, and inspecting the output. Each model demo notebook should stand on its own, focused on one model or a small family of related models.
# keywords: model demo, placeholder
# other-links:
#   - text: "Launch on Binder"
#     href: "https://mybinder.org/v2/gh/LinkedEarth/Ammonyte/HEAD?labpath=notebooks/model_demos/placeholder.ipynb"
#     icon: rocket-takeoff
#   - text: "Download notebook"
#     href: "https://raw.githubusercontent.com/LinkedEarth/Ammonyte/main/notebooks/model_demos/placeholder.ipynb"
#     icon: download
# ---

# %%
import ammonyte

print(f"Ammonyte model demo — replace this cell with a real example.")
