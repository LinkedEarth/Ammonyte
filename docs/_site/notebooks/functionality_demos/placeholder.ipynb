# %% [raw]
# ---
# title: "Functionality Demos — Placeholder"
# author: "Maryam Niati, Alexander James, Julien Emile-Geay, Deborah Khider"
# date: last-modified
# abstract: >
#   Replace this cell with a focused example of one utility — what problem it solves, its signature, and a small before/after comparison if applicable. Keep functionality demos narrow; one notebook per utility or closely related group of utilities.
# keywords: functionality demo, placeholder
# other-links:
#   - text: "Launch on Binder"
#     href: "https://mybinder.org/v2/gh/LinkedEarth/Ammonyte/HEAD?labpath=notebooks/functionality_demos/placeholder.ipynb"
#     icon: rocket-takeoff
#   - text: "Download notebook"
#     href: "https://raw.githubusercontent.com/LinkedEarth/Ammonyte/main/notebooks/functionality_demos/placeholder.ipynb"
#     icon: download
# ---

# %%
import ammonyte

print(f"Ammonyte functionality demo — replace this cell with a real example.")
